# %% [markdown]
# # Time Series window data 생성 및 모델별 성능 비교
#
# 1. Persistence algorithm 을 이용한 forecasting
# 2. simple 1 layer NN 을 이용한 forecasting
# 3. Deep NN을  이용한 forecasting
# 4. LSTM 을  이용한 forecasting

# %% [markdown]
# ## Sunspots 데이터셋을 활용하여 window_dataset 만들기

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd

url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
df = pd.read_csv(url, skiprows=0, index_col=0) # 첫 줄은 header이므로 skip 
df.head()
# Out:
#          Date  Monthly Mean Total Sunspot Number
# 0  1749-01-31                               96.7
# 1  1749-02-28                              104.3
# 2  1749-03-31                              116.7
# 3  1749-04-30                               92.8
# 4  1749-05-31                              141.7

# %%
df.tail()
# Out:
#             Date  Monthly Mean Total Sunspot Number
# 3230  2018-03-31                                2.5
# 3231  2018-04-30                                8.9
# 3232  2018-05-31                               13.2
# 3233  2018-06-30                               15.9
# 3234  2018-07-31                                1.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3235 entries, 0 to 3234
# Data columns (total 2 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               3235 non-null   object
#  1   Monthly Mean Total Sunspot Number  3235 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 75.8+ KB

# %% [markdown]
# - 시간 절약을 위해 최근 500 개월치 data 만 이용
#
# time 변수는 DataFrame의 마지막 500개 행의 첫 번째 열(0번 인덱스)에 해당하는 값을 포함하고 있습니다. time_series 변수는 마지막 500개 행의 두 번째 열(1번 인덱스)에 해당하는 값을 포함하고 있습니다.

# %%
time = df.iloc[-500:, 0].values
time_series = df.iloc[-500:, 1].values
time.shape, time_series.shape
# Out:
# ((500,), (500,))

# %% [markdown]
# ## Supervised Learning dataset 작성
#
# - Persistent Algorithm 과 비교하기 위해 Many-to-One style 로 예측
#
# windowed_dataset 함수는 다음 단계를 수행합니다:
#
# 1. series를 입력으로 받아 tf.data.Dataset.from_tensor_slices() 함수를 사용하여 TensorFlow Dataset 객체를 생성합니다.
# 2. ds.window() 함수를 사용하여 데이터를 겹치는 윈도우로 분할합니다. 윈도우 크기는 window_size+1로 설정하며, 각 윈도우는 1씩 이동(shift)합니다. drop_remainder=True를 설정하여 길이가 부족한 마지막 윈도우를 제거합니다.
# 3. ds.flat_map() 함수를 사용하여 각 윈도우를 일련의 데이터 포인트로 평평하게(flatten) 만듭니다.
# 4. ds.shuffle() 함수를 사용하여 데이터를 섞습니다. shuffle_buffer 매개 변수는 셔플링에 사용되는 버퍼 크기를 결정합니다.
# 5. ds.map() 함수를 사용하여 각 윈도우의 마지막 데이터 포인트를 레이블로 설정하고 나머지를 입력 특성으로 사용합니다. 즉, 각 윈도우에서 하나의 출력 값(single step output)이 생성됩니다.
# 6. ds.batch() 함수를 사용하여 데이터를 batch_size 크기의 배치로 구성하고, ds.prefetch(1)을 사용하여 학습 중에 다음 배치를 미리 가져옵니다.

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size+1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size+1))
    ds = ds.shuffle(shuffle_buffer).map(lambda w: (w[:-1], w[-1]))   # single step output
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %% [markdown]
# ### train/validation set 분리

# %%
split_time = 450

time_train = time[:split_time]
time_test = time[split_time:]

X_train = time_series[:split_time]
X_test  = time_series[split_time:]

len(time_train), len(time_test), len(X_train), len(X_test)
# Out:
# (450, 50, 450, 50)

# %%
window_size = 30
batch_size = 64
shuffle_buffer_size = 1000

train_ds = windowed_dataset(X_train, window_size, batch_size, shuffle_buffer_size)
train_ds
# Out:
# WARNING:tensorflow:From C:\Users\trimu\anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.float64, name=None))>

# %%
for x, y in train_ds:
    print('x = ', x.numpy().shape)
    print('y = ', y.numpy().shape)
    break
# Out:
# x =  (64, 30)
# y =  (64,)

# %% [markdown]
# ## 1. Persistence algorithm 을 이용한 forecasting
#
# - Persistence Algorithm : last value 를 next value 로 예측에 사용
#
# naive_forecast는 주어진 시계열 데이터의 단순한 예측값을 생성합니다. 여기서는 테스트 데이터셋의 이전 값(즉, 마지막 훈련 데이터셋의 값)을 사용하여 테스트 데이터셋을 예측합니다. 이 예측 방법은 매우 단순하며 실제로는 복잡한 패턴을 예측할 수 없지만, 복잡한 모델과의 성능 비교를 위한 기준점으로 사용할 수 있습니다.
#
# naive_forecast에 저장된 처음 10개의 예측값은 다음과 같습니다:

# %%
naive_forecast = time_series[split_time-1:-1]
naive_forecast[:10]
# Out:
# array([112.5, 102.9, 100.2, 106.9, 130. ,  90. , 103.6, 112.9,  93. ,
#         66.7])

# %%
X_test[:10]
# Out:
# array([102.9, 100.2, 106.9, 130. ,  90. , 103.6, 112.9,  93. ,  66.7,
#         54.5])

# %% [markdown]
# 테스트 데이터셋과 naive_forecast 사이의 평균 제곱 오차(Mean Squared Error, MSE)와 평균 절대 오차(Mean Absolute Error, MAE)를 계산합니다.
# 일반적으로 낮은 값이 더 좋은 예측 성능을 나타냅니다.

# %%
print(mean_squared_error(X_test, naive_forecast))
print(mean_absolute_error(X_test, naive_forecast))
# Out:
# 194.96940000000004
# 10.737999999999998

# %%
compare_models = {}

compare_models['persistence'] = \
     [mean_squared_error(X_test, naive_forecast), mean_absolute_error(X_test, naive_forecast)]

# %% [markdown]
# ## 2. simple 1 layer NN 을 이용한 forecasting - Linear Regression
#
# input_shape: 입력 데이터의 형태를 지정합니다. 여기서 입력 데이터의 형태는 [window_size]입니다.
# 이 모델은 각 시계열 윈도우에 대해 하나의 출력 값을 예측합니다. 이 간단한 모델은 선형 회귀와 유사하게 작동하며, 시계열 데이터의 간단한 패턴을 포착할 수 있습니다.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_shape=[window_size])
])

model.compile(loss='mse', optimizer='adam')
model.fit(train_ds, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 119ms/step - loss: 35727.6172
# Epoch 2/100
# 7/7 [==============================] - 0s 1ms/step - loss: 27881.9141
# Epoch 3/100
# 7/7 [==============================] - 0s 936us/step - loss: 21204.6484
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 15913.1582
# Epoch 5/100
# 7/7 [==============================] - 0s 995us/step - loss: 11871.0264
# Epoch 6/100
# 7/7 [==============================] - 0s 855us/step - loss: 8939.1592
# Epoch 7/100
# 7/7 [==============================] - 0s 795us/step - loss: 6911.7100
# Epoch 8/100
# 7/7 [==============================] - 0s 988us/step - loss: 5630.0098
100
# 7/7 [==============================] - 0s 1ms/step - loss: 1415.3635

# %% [markdown]
# X_test 와 prediction 을 비교해야 하므로 time_series의 window_size ~ 끝까지를 forecast 하고 X_test 와 같은 길이의 마지막 ` time_series[-len(X_test):]`를 result 로 저장 합니다.

# %% [markdown]
# split_time - window_size는 시계열 데이터의 끝에서 window_size 만큼 뺀 위치에 해당합니다. 이 값은 훈련 데이터와 테스트 데이터를 분할하는 인덱스를 기준으로, 훈련 데이터에 포함된 윈도우의 마지막 시작 위치를 나타냅니다.
# len(time_series)는 시계열 데이터의 전체 길이를 나타냅니다.
#
# 예를 들어, split_time이 450이고 window_size가 30이라면, split_time - window_size는 420이 됩니다. 이는 훈련 데이터의 마지막 윈도우가 시계열 데이터의 420번 인덱스에서 시작한다는 것을 의미합니다. 시계열 데이터의 전체 길이는 len(time_series)로 확인할 수 있습니다.

# %%
split_time - window_size, len(time_series)
# Out:
# (420, 500)

# %% [markdown]
# 아래 코드의 forecast 는 테스트 데이터의 각 시간 단계에 대한 예측을 포함합니다. for loop는 split_time부터 시작하여 시계열의 끝까지 진행되며, 이전 window_size 시간 단계를 사용하여 각 단계에 대한 예측을 수행합니다.
#
# 이 예에서, 만약 split_time이 450이고 시계열의 전체 길이(len(time_series))가 500이라면, 루프는 450부터 499까지 반복됩니다. forecast 리스트의 길이는 테스트 데이터의 길이와 같으며, 이는 500 - 450 = 50입니다.

# %%
forecast = []

for time in range(split_time, len(time_series)):
    prediction = model.predict(time_series[time-window_size:time].reshape(1, -1), verbose=0)
    forecast.append(prediction[0][0])

# %%
plt.figure(figsize=(16, 6))
plt.plot(time_test, X_test, label='true value')
plt.plot(time_test, forecast, label='forecast')
plt.xticks(rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
print(tf.keras.metrics.mean_squared_error(X_test, forecast).numpy())
print(tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy())
# Out:
# 524.8562
# 18.31347

# %%
compare_models['1 Layer Dense'] = \
     [tf.keras.metrics.mean_squared_error(X_test, forecast).numpy(), 
      tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy()]
compare_models
# Out:
# {'persistence': [194.96940000000004, 10.737999999999998],
#  '1 Layer Dense': [524.8562, 18.31347]}

# %% [markdown]
# ## 3. Deep NN을  이용한 forecasting

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, input_shape=[window_size], activation="relu"), 
    tf.keras.layers.Dense(10, activation="relu"), 
    tf.keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer='adam')

history = model.fit(train_ds,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1943.9034
# Epoch 2/100
# 7/7 [==============================] - 0s 1ms/step - loss: 884.3577
# Epoch 3/100
# 7/7 [==============================] - 0s 1ms/step - loss: 866.2449
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 712.3020
# Epoch 5/100
# 7/7 [==============================] - 0s 1ms/step - loss: 681.2946
# Epoch 6/100
# 7/7 [==============================] - 0s 1ms/step - loss: 629.8282
# Epoch 7/100
# 7/7 [==============================] - 0s 1ms/step - loss: 655.2538
# Epoch 8/100
# 7/7 [==============================] - 0s 1ms/step - loss: 583.1286
# Epoch 9/100
# 7/7 [==============================] - 0s 1ms/step - loss: 606.2979
# Epoch 10/100
# 7/7 [==============================] - 0s 1ms/step - loss: 606.0339
# Epoch 11/100
# 7/7 [==============================] - 0s 1ms/step - loss: 603.2285
# Epoch 12/100
# 7/7 [==============================] - 0s 1ms/step - loss: 575.0959
# Epoch 13/100
# 7/7 [==============================] - 0s 1ms/step - loss: 553.3339
# Epoch 14/100
# 7/7 [==============================] - 0s 1ms/step - loss: 336.9444
# Epoch 92/100
# 7/7 [==============================] - 0s 973us/step - loss: 339.7854
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 323.4504
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 326.4272
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 317.9156
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 327.4350
# Epoch 97/100
# 7/7 [==============================] - 0s 819us/step - loss: 335.6431
# Epoch 98/100
# 7/7 [==============================] - 0s 995us/step - loss: 365.0219
# Epoch 99/100
# 7/7 [==============================] - 0s 954us/step - loss: 415.5102
# Epoch 100/100
# 7/7 [==============================] - 0s 963us/step - loss: 370.4995

# %%
forecast = []

for time in range(split_time, len(time_series)):
    prediction = model.predict(time_series[time-window_size:time].reshape(1, -1), verbose=0)
    forecast.append(prediction[0][0])

plt.figure(figsize=(16, 6))
plt.plot(time_test, X_test, label='true value')
plt.plot(time_test, forecast, label='forecast')
plt.xticks(rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
print(tf.keras.metrics.mean_squared_error(X_test, forecast).numpy())
print(tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy())
# Out:
# 168.01172
# 10.231586

# %%
compare_models['Deep NN'] = \
     [tf.keras.metrics.mean_squared_error(X_test, forecast).numpy(), 
      tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy()]
compare_models
# Out:
# {'persistence': [194.96940000000004, 10.737999999999998],
#  '1 Layer Dense': [524.8562, 18.31347],
#  'Deep NN': [168.01172, 10.231586]}

# %% [markdown]
# ## 4. LSTM 을  이용한 forecasting
#
# - RNN 은 3 Dimension input 이 필요하므로 Lambda layer 를 이용하여 2D $\rightarrow$ 3D expand

# %% [markdown]
# ### 4-1. Simple LSTM

# %% [markdown]
# - 첫 번째 람다 레이어는 차원을 확장하는 데 도움이 됩니다. 여기서는 배열을 1차원 확장하고 모델이 모든 길이의 시퀀스를 사용할 수 있음을 의미하는 input_shape=[None]을 설정 합니다.
#
# - 최종 람다 계층은 출력을 100배 확장하여 훈련에 도움이 될 수 있습니다. RNN의 기본 레이어는 -1과 1 사이의 값을 출력하는 tanh입니다. 출력을 스케일링하면 이러한 값을 일반적으로 40, 50, 60 등의 값인 시계열에 더 가깝게 만들 수 있습니다.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None]),
    tf.keras.layers.LSTM(32, input_shape=[window_size, 1]),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100.0)
    ])

model.compile(loss='mse', optimizer='adam')
history = model.fit(train_ds, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 8ms/step - loss: 4721.1948
# Epoch 2/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3421.0928
# Epoch 3/100
# 7/7 [==============================] - 0s 6ms/step - loss: 2669.6387
# Epoch 4/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2048.2397
# Epoch 5/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1500.2417
# Epoch 6/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1192.1948
# Epoch 7/100
# 7/7 [==============================] - 0s 6ms/step - loss: 
# 7/7 [==============================] - 0s 6ms/step - loss: 545.2550
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 551.7203
# Epoch 90/100
# 7/7 [==============================] - 0s 6ms/step - loss: 543.9209
# Epoch 91/100
# 7/7 [==============================] - 0s 6ms/step - loss: 539.7007
# Epoch 92/100
# 7/7 [==============================] - 0s 6ms/step - loss: 540.0364
# Epoch 93/100
# 7/7 [==============================] - 0s 6ms/step - loss: 536.2772
# Epoch 94/100
# 7/7 [==============================] - 0s 7ms/step - loss: 543.9607
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 544.8793
# Epoch 96/100
# 7/7 [==============================] - 0s 7ms/step - loss: 538.6400
# Epoch 97/100
# 7/7 [==============================] - 0s 6ms/step - loss: 546.8519
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 545.0863
# Epoch 99/100
# 7/7 [==============================] - 0s 6ms/step - loss: 574.5607
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 546.0330

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, None, 1)           0
#
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense_4 (Dense)             (None, 1)                 33
#
#  lambda_1 (Lambda)           (None, 1)                 0
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
forecast = []

for time in range(split_time, len(time_series)):
    prediction = model.predict(time_series[time-window_size:time].reshape(1, -1), verbose=0)
    forecast.append(prediction[0][0])

plt.figure(figsize=(16, 6))
plt.plot(time_test, X_test, label='true value')
plt.plot(time_test, forecast, label='forecast')
plt.xticks(rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
print(tf.keras.metrics.mean_squared_error(X_test, forecast).numpy())
print(tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy())
# Out:
# 152.03777
# 10.249384

# %%
compare_models['Simple LSTM'] = \
     [tf.keras.metrics.mean_squared_error(X_test, forecast).numpy(), 
      tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy()]
compare_models
# Out:
# {'persistence': [194.96940000000004, 10.737999999999998],
#  '1 Layer Dense': [524.8562, 18.31347],
#  'Deep NN': [168.01172, 10.231586],
#  'Simple LSTM': [152.03777, 10.249384]}

# %% [markdown]
# ### 4-2. Stacked + Bidirectoinal LSTM
#
# 이 코드는 양방향 LSTM 모델을 정의합니다. 여기에 포함된 각 층은 다음과 같습니다:
#
# Lambda 층: 입력 데이터의 마지막 축을 확장하여 형태를 [None]에서 [None, 1]로 변경합니다. 이렇게 하면 입력 데이터를 2D에서 3D로 변환하여 LSTM 층에 적합한 형태로 만듭니다.
#
# Bidirectional 층: 양방향 LSTM을 사용하여 시계열 데이터를 처리합니다. 첫 번째 양방향 LSTM 층은 32개의 유닛을 가지며, return_sequences=True로 설정되어 있어 시퀀스 전체를 출력합니다. 이렇게 하면 이 층의 출력이 다음 LSTM 층의 입력으로 사용될 수 있습니다.
#
# 또 다른 Bidirectional 층: 두 번째 양방향 LSTM 층 역시 32개의 유닛을 가지고 있지만, return_sequences의 기본값인 False로 설정되어 마지막 시간 단계의 출력만 반환합니다.
#
# Dense 층: 출력 유닛이 1개인 완전 연결 층입니다. 이 층은 LSTM 층에서 얻은 정보를 바탕으로 시계열 데이터의 다음 값을 예측하는 역할을 합니다.
#
# 마지막 Lambda 층: 출력 값을 100배로 스케일업합니다. 이렇게 하면 네트워크가 더 큰 값의 범위를 예측할 수 있게 됩니다.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1
# Epoch 75/100
# 7/7 [==============================] - 0s 16ms/step - loss: 565.5060
# Epoch 76/100
# 7/7 [==============================] - 0s 16ms/step - loss: 549.5963
# Epoch 77/100
# 7/7 [==============================] - 0s 17ms/step - loss: 543.8558
# Epoch 78/100
# 7/7 [==============================] - 0s 17ms/step - loss: 541.4067
# Epoch 79/100
# 7/7 [==============================] - 0s 17ms/step - loss: 547.7863
# Epoch 80/100
# 7/7 [==============================] - 0s 16ms/step - loss: 556.3999
# Epoch 81/100
# 7/7 [==============================] - 0s 16ms/step - loss: 558.8690
# Epoch 82/100
# 7/7 [==============================] - 0s 15ms/step - loss: 568.9025
# Epoch 83/100
# 7/7 [==============================] - 0s 16ms/step - loss: 575.3317
# Epoch 84/100
# 7/7 [==============================] - 0s 16ms/step - loss: 537.2477
# Epoch 85/100
# 7/7 [==============================] - 0s 17ms/step - loss: 532.3094
# Epoch 86/100
# 7/7 [==============================] - 0s 16ms/step - loss: 531.3073
# Epoch 87/100
# 7/7 [==============================] - 0s 16ms/step - loss: 541.8788
# Epoch 88/100
# 7/7 [==============================] - 0s 16ms/step - loss: 525.9865
# Epoch 89/100
# 7/7 [==============================] - 0s 16ms/step - loss: 546.5203
# Epoch 90/100
# 7/7 [==============================] - 0s 16ms/step - loss: 527.4276
# Epoch 91/100
# 7/7 [==============================] - 0s 16ms/step - loss: 546.0975
# Epoch 92/100
# 7/7 [==============================] - 0s 17ms/step - loss: 554.5083
# Epoch 93/100
# 7/7 [==============================] - 0s 16ms/step - loss: 527.9237
# Epoch 94/100
# 7/7 [==============================] - 0s 16ms/step - loss: 524.9315
# Epoch 95/100
# 7/7 [==============================] - 0s 17ms/step - loss: 520.0959
# Epoch 96/100
# 7/7 [==============================] - 0s 16ms/step - loss: 519.9775
# Epoch 97/100
# 7/7 [==============================] - 0s 16ms/step - loss: 529.4752
# Epoch 98/100
# 7/7 [==============================] - 0s 16ms/step - loss: 531.5876
# Epoch 99/100
# 7/7 [==============================] - 0s 16ms/step - loss: 517.6857
# Epoch 100/100
# 7/7 [==============================] - 0s 16ms/step - loss: 570.4316

# %%
forecast = []

for time in range(split_time, len(time_series)):
    prediction = model.predict(time_series[time-window_size:time].reshape(1, -1), verbose=0)
    forecast.append(prediction[0][0])

plt.figure(figsize=(16, 6))
plt.plot(time_test, X_test, label='true value')
plt.plot(time_test, forecast, label='forecast')
plt.xticks(rotation=90)
plt.legend(fontsize=15)
plt.show()

# %%
print(tf.keras.metrics.mean_squared_error(X_test, forecast).numpy())
print(tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy())
# Out:
# 240.81224
# 12.029283

# %%
compare_models['Stacked Bidirectional LSTM'] = \
     [tf.keras.metrics.mean_squared_error(X_test, forecast).numpy(), 
      tf.keras.metrics.mean_absolute_error(X_test, forecast).numpy()]
compare_models
# Out:
# {'persistence': [194.96940000000004, 10.737999999999998],
#  '1 Layer Dense': [524.8562, 18.31347],
#  'Deep NN': [168.01172, 10.231586],
#  'Simple LSTM': [152.03777, 10.249384],
#  'Stacked Bidirectional LSTM': [240.81224, 12.029283]}
