# %% [markdown]
# # Conv1D input layer
#
#
# - Sliding Window Data 생성
#
# - Conv1D + LSTM model 작성
#
# - Learning Rate Tunning
#
# - Window Size Tuning

# %% [markdown]
# ### Sunspots 데이터셋을 활용하여 window_dataset 만들기

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd
np.random.seed(42)
tf.random.set_seed(51)

url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
df = pd.read_csv(url, skiprows=0, index_col=0)   #첫 줄은 header이므로 skip
df.shape
# Out:
# (3235, 2)

# %%
df.head()
# Out:
#          Date  Monthly Mean Total Sunspot Number
# 0  1749-01-31                               96.7
# 1  1749-02-28                              104.3
# 2  1749-03-31                              116.7
# 3  1749-04-30                               92.8
# 4  1749-05-31                              141.7

# %% [markdown]
# Data 시각화

# %%
# 'Monthly Mean Total Sunspot Number' 컬럼을 numpy 배열로 추출
series = df['Monthly Mean Total Sunspot Number'].values
time = range(series.size)  # 시간 인덱스 생성 (0 ~ 데이터 크기-1)
print(series.size)         # 전체 데이터 크기 출력

# 전체 시계열 데이터 시각화
plt.figure(figsize=(12, 4))
plt.plot(time, series)
plt.xlabel("Time")
plt.ylabel("No. of monthly sunspots")  # 월별 흑점 수
plt.grid(True)
# Out:
# 3235

# %% [markdown]
# - 시간 절약을 위해 최근 1000 개월치 data 만 이용

# %%
time = df.iloc[-1000:, 0].values
time_series = df.iloc[-1000:, 1].values
time.shape, time_series.shape
# Out:
# ((1000,), (1000,))

# %% [markdown]
# ### windowed dataset 생성
#
# 1. series를 이용해 tf.data.Dataset.from_tensor_slices로 데이터셋을 생성합니다.
# 2. ds.window를 사용하여 입력 데이터셋을 지정한 윈도우 크기와 함께 슬라이딩 윈도우 방식으로 나눕니다.   drop_remainder=True는 윈도우 크기보다 작은 마지막 윈도우를 제거합니다.
# 3. ds.flat_map을 사용하여 각 윈도우를 하나의 배치로 펼칩니다.
# 4. ds.shuffle을 사용하여 데이터셋을 무작위로 섞습니다. 이렇게 하면 모델이 훈련 데이터의 순서를 기억하는 것을 방지할 수 있습니다.
# 5. ds.map에서 입력 데이터의 마지막 원소를 제외한 부분을 X로 사용하고, 첫 원소를 제외한 부분을 y로 사용하여 다중 스텝 출력을 준비합니다.
# 6. 마지막으로, ds.batch를 사용하여 지정된 배치 크기로 데이터를 나누고, ds.prefetch를 사용하여 효율적인 학습을 위해 데이터를 미리 가져옵니다.
#
# **이전 버전과의 차이점:**
# ```
# w[:-1], w[-1]  → 마지막 단일 값 예측
# w[:-1], w[1:]  → 다음 시퀀스 전체 예측 (multi-step)
# ```

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    # 시계열 데이터를 TensorFlow Dataset으로 변환
    ds = tf.data.Dataset.from_tensor_slices(series)

    # 슬라이딩 윈도우 적용 (window_size+1 : 입력 + 정답 시퀀스 포함, 크기 미달 윈도우 제거)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)

    # 중첩 Dataset을 1D 텐서로 변환
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))

    # 셔플 후 입력(X)과 정답(y) 분리 - multi-step output (many-to-many)
    # w[:-1] : 앞 window_size개 → 입력 시퀀스 (X)
    # w[1:]  : 뒤 window_size개 → 정답 시퀀스 (y) ← 한 칸씩 뒤로 이동
    ds = ds.shuffle(shuffle_buffer).map(lambda w: (w[:-1], w[1:]))

    # 미니배치 구성 및 다음 배치 미리 준비 (학습 속도 향상)
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %% [markdown]
# #### Forecast Helper Function
#
# - training 후 series data를 model 입력 사양에 맞추어 예측하기 위해 사용 (batch, shuffle 제외)
# - 지도학습 label 불필요하므로 window size 에 +1 을 해줄 필요 없습니다.
#
# **`windowed_dataset` vs `model_forecast` 비교:**
# ```
# windowed_dataset  (학습용)          model_forecast  (예측용)
# window_size + 1  ← 정답 포함       window_size     ← 입력만 (정답 불필요)
# map(X, y 분리)   ← 정답 생성        map 없음        ← X만 생성
# shuffle 있음     ← 순서 섞기        shuffle 없음    ← 순서 유지 필수
# batch(batch_size)                  batch(1)        ← 한 번에 1개씩 예측
# ```

# %%
def model_forecast(model, series, window_size):
    # 시계열 데이터를 TensorFlow Dataset으로 변환
    ds = tf.data.Dataset.from_tensor_slices(series)

    # 슬라이딩 윈도우 적용 (예측용이므로 정답 불필요 → window_size만큼만 슬라이싱)
    ds = ds.window(window_size, shift=1, drop_remainder=True)

    # 중첩 Dataset을 1D 텐서로 변환
    ds = ds.flat_map(lambda w: w.batch(window_size))

    # 배치 크기=1로 묶고 다음 배치 미리 준비
    ds = ds.batch(1).prefetch(1)

    # 모델로 예측 수행
    forecast = model.predict(ds)
    return forecast

# %% [markdown]
# ### train/validation set 분리

# %%
# 학습/테스트 데이터 분리 기준점 설정 (700번째 시점 기준)
split_time = 700

# 시간 인덱스 분리
time_train = time[:split_time]   # 학습 구간 시간 인덱스
time_test  = time[split_time:]   # 테스트 구간 시간 인덱스

# 시계열 값 분리
X_train = time_series[:split_time]  # 학습 데이터
X_test  = time_series[split_time:]  # 테스트 데이터

# 각 데이터 크기 확인
len(time_train), len(time_test), len(X_train), len(X_test)
# Out:
# (700, 300, 700, 300)

# %%
window_size = 132  #132, 64, 30
batch_size = 64
shuffle_buffer_size = 1000

train_ds = windowed_dataset(X_train, window_size, batch_size, shuffle_buffer_size)
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float64, name=None), TensorSpec(shape=(None, None), dtype=tf.float64, name=None))>

# %% [markdown]
# ## Conv1D + LSTM + Bidirectional
#
# - Causal Convolution(인과관계 컨벌루션)은 시간 t의 출력이 시간 t - 1의 입력에서만 파생되도록 합니다.
#
# - Causal padding 은 `Conv1D`에만 지원됩니다.
#
# <img src="https://user-images.githubusercontent.com/24662250/29258799-9b3ff514-80f7-11e7-83e4-ab701fdc2720.png" width=500 />
#
# Causal Convolution(인과 관계 컨벌루션)은 시계열 데이터를 처리할 때 사용되는 기법입니다. 시간 t의 출력이 시간 t 이전의 데이터로만 생성되기 때문에 인과 관계를 유지할 수 있습니다. 이 방법은 미래 데이터를 참조하지 않고 현재 및 과거 데이터만 사용하여 미래를 예측할 수 있게 합니다.
#
# Causal padding은 인과 관계 컨벌루션을 구현하기 위한 패딩 기법입니다. 일반적인 컨벌루션과 달리, causal padding은 입력의 오른쪽 끝(또는 시계열 데이터의 미래 부분)에는 패딩을 추가하지 않고 입력의 왼쪽 끝(또는 시계열 데이터의 과거 부분)에만 패딩을 추가합니다. 이로 인해 컨볼루션 필터는 현재 및 과거 값에만 접근할 수 있으며, 미래 데이터는 참조하지 않게 됩니다.
#
# TensorFlow에서는 Conv1D 레이어를 사용하여 인과 관계 컨벌루션을 구현할 수 있습니다. 이를 위해 padding='causal' 인자를 사용하면 됩니다.

# %%
def model_define(kernel_size):
    model = tf.keras.models.Sequential([
      tf.keras.layers.Input(shape=[None, 1]),
      tf.keras.layers.Conv1D(filters=32, kernel_size=kernel_size, strides=1, padding="causal",
                             activation="relu"),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
      tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
      tf.keras.layers.Dense(1),
    ])
    return model

# %% [markdown]
# - 초기 epoch 100 동안 learning rate를 변경해 가며 loss가  증가하지 않는 가장 큰 learning rate 를 찾아냅니다.
#
# **학습률 스케줄러 동작 방식:**
# ```
# epoch  0 : 1e-8 * 10^(0/20)  = 1e-8
# epoch 20 : 1e-8 * 10^(20/20) = 1e-7
# epoch 40 : 1e-8 * 10^(40/20) = 1e-6
# epoch 60 : 1e-8 * 10^(60/20) = 1e-5
# epoch 80 : 1e-8 * 10^(80/20) = 1e-4
# epoch 100: 1e-8 * 10^(100/20)= 1e-3
# ```

# %%
# 커널 크기=5로 Conv1D + Bidirectional LSTM 모델 생성
model = model_define(kernel_size=5)

# 최적 학습률 탐색을 위한 학습률 스케줄러 정의
# epoch 증가에 따라 학습률을 1e-8 → 1e-8 * 10^5 까지 점진적으로 증가
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20)
)

# SGD 옵티마이저 설정 (초기 학습률=1e-8, momentum=0.9)
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=0.9)

# 모델 컴파일
model.compile(
    loss=tf.keras.losses.Huber(),  # Huber 손실함수: 이상치에 강건한 MSE+MAE 혼합
    optimizer=optimizer,
    metrics=["mae"]                # 평가지표: 평균 절대 오차
)

# 모델 학습 (학습률 스케줄러 적용)
history = model.fit(train_ds, epochs=100, verbose=1, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 107.3777 - mae: 107.8747 - learning_rate: 1.0000e-08
# Epoch 2/100
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - loss: 108.7072 - mae: 109.2041
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.1647 - mae: 108.6616 - learning_rate: 1.1220e-08
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.6398 - mae: 109.1366 - learning_rate: 1.2589e-08
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.1951 - mae: 108.6919 - learning_rate: 1.4125e-08
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 108.4731 - mae: 108.9698 - learning_rate: 1.5849e-08
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.0397 - mae: 108.5365 - learning_rate: 1.7783e-08
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.8505 - mae: 108.3472 - learning_rate: 1.9953e-08
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 108.4365 - mae: 108.9334 - learning_rate: 2.2387e-08
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.0840 - mae: 108.5807 - learning_rate: 2.5119e-08
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.4279 - mae: 107.9248 - learning_rate: 2.8184e-08
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.8738 - mae: 109.3704 - learning_rate: 3.1623e-08
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 108.1227 - mae: 108.6195 - learning_rate: 3.5481e-08
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 108.3387 - mae: 108.8355 - learning_rate: 3.9811e-08
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 108.2780 - mae: 108.7746 - learning_rate: 4.4668e-08
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 108.4324 - mae: 108.9292 - learning_rate: 5.0119e-08
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.0501 - mae: 108.5469 - learning_rate: 5.6234e-08
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 109.0598 - mae: 109.5565 - learning_rate: 6.3096e-08
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 108.1650 - mae: 108.6617 - learning_rate: 7.0795e-08
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.2962 - mae: 108.7929 - learning_rate: 7.9433e-08
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.0510 - mae: 108.5476 - learning_rate: 8.9125e-08
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 108.3270 - mae: 108.8237 - learning_rate: 1.0000e-07
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.2815 - mae: 108.7780 - learning_rate: 1.1220e-07
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.7050 - mae: 109.2015 - learning_rate: 1.2589e-07
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.1643 - mae: 108.6609 - learning_rate: 1.4125e-07
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.6618 - mae: 109.1584 - learning_rate: 1.5849e-07
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.4841 - mae: 108.9809 - learning_rate: 1.7783e-07
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.9745 - mae: 108.4712 - learning_rate: 1.9953e-07
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.2248 - mae: 108.7214 - learning_rate: 2.2387e-07
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 109.0655 - mae: 109.5621 - learning_rate: 2.5119e-07
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.2312 - mae: 108.7278 - learning_rate: 2.8184e-07
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 107.7676 - mae: 108.2644 - learning_rate: 3.1623e-07
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.1924 - mae: 108.6892 - learning_rate: 3.5481e-07
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.7823 - mae: 109.2790 - learning_rate: 3.9811e-07
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 107.7623 - mae: 108.2589 - learning_rate: 4.4668e-07
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.9575 - mae: 109.4541 - learning_rate: 5.0119e-07
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.6476 - mae: 108.1442 - learning_rate: 5.6234e-07
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.9469 - mae: 109.4434 - learning_rate: 6.3096e-07
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 107.8273 - mae: 108.3238 - learning_rate: 7.0795e-07
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.8920 - mae: 108.3888 - learning_rate: 7.9433e-07
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.2128 - mae: 108.7095 - learning_rate: 8.9125e-07
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 107.6733 - mae: 108.1701 - learning_rate: 1.0000e-06
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.4207 - mae: 108.9175 - learning_rate: 1.1220e-06
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.1837 - mae: 108.6804 - learning_rate: 1.2589e-06
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 108.2649 - mae: 108.7616 - learning_rate: 1.4125e-06
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 108.2609 - mae: 108.7575 - learning_rate: 1.5849e-06
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 108.5264 - mae: 109.0230 - learning_rate: 1.7783e-06
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 108.3667 - mae: 108.8635 - learning_rate: 1.9953e-06
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 108.0368 - mae: 108.5335 - learning_rate: 2.2387e-06
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 107.7185 - mae: 108.2154 - learning_rate: 2.5119e-06
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 107.9802 - mae: 108.4769 - learning_rate: 2.8184e-06
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 108.6317 - mae: 109.1285 - learning_rate: 3.1623e-06
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - loss: 108.1214 - mae: 108.6182 - learning_rate: 3.5481e-06
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 107.4919 - mae: 107.9888 - learning_rate: 3.9811e-06
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 107.8887 - mae: 108.3856 - learning_rate: 4.4668e-06
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.5438 - mae: 109.0407 - learning_rate: 5.0119e-06
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.3405 - mae: 108.8374 - learning_rate: 5.6234e-06
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 108.3539 - mae: 108.8508 - learning_rate: 6.3096e-06
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.3797 - mae: 107.8768 - learning_rate: 7.0795e-06
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 108.0711 - mae: 108.5684 - learning_rate: 7.9433e-06
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 108.3391 - mae: 108.8363 - learning_rate: 8.9125e-06
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 107.8604 - mae: 108.3578 - learning_rate: 1.0000e-05
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 107.5014 - mae: 107.9988 - learning_rate: 1.1220e-05
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 107.4226 - mae: 107.9203 - learning_rate: 1.2589e-05
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.3685 - mae: 108.8661 - learning_rate: 1.4125e-05
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.5173 - mae: 108.0152 - learning_rate: 1.5849e-05
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 108.1417 - mae: 108.6396 - learning_rate: 1.7783e-05
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.7599 - mae: 108.2580 - learning_rate: 1.9953e-05
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.1454 - mae: 107.6437 - learning_rate: 2.2387e-05
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.3170 - mae: 107.8155 - learning_rate: 2.5119e-05
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 107.2206 - mae: 107.7193 - learning_rate: 2.8184e-05
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 106.5998 - mae: 107.0986 - learning_rate: 3.1623e-05
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.5814 - mae: 108.0801 - learning_rate: 3.5481e-05
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 106.2738 - mae: 106.7726 - learning_rate: 3.9811e-05
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 107.0096 - mae: 107.5085 - learning_rate: 4.4668e-05
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 106.8962 - mae: 107.3951 - learning_rate: 5.0119e-05
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 106.4939 - mae: 106.9931 - learning_rate: 5.6234e-05
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 106.1560 - mae: 106.6553 - learning_rate: 6.3096e-05
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 500ms/step - loss: 106.6046 - mae: 107.1038 - learning_rate: 7.0795e-05
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 106.9520 - mae: 107.4510 - learning_rate: 7.9433e-05
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 106.4893 - mae: 106.9880 - learning_rate: 8.9125e-05
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 105.9564 - mae: 106.4543 - learning_rate: 1.0000e-04
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 106.4553 - mae: 106.9527 - learning_rate: 1.1220e-04
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 105.6229 - mae: 106.1203 - learning_rate: 1.2589e-04
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 104.8021 - mae: 105.3000 - learning_rate: 1.4125e-04
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 104.9569 - mae: 105.4550 - learning_rate: 1.5849e-04
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 105.1264 - mae: 105.6246 - learning_rate: 1.7783e-04
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 104.4956 - mae: 104.9935 - learning_rate: 1.9953e-04
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 104.1059 - mae: 104.6043 - learning_rate: 2.2387e-04
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 104.0324 - mae: 104.5314 - learning_rate: 2.5119e-04
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 103.2094 - mae: 103.7080 - learning_rate: 2.8184e-04
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 102.8446 - mae: 103.3431 - learning_rate: 3.1623e-04
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 102.2939 - mae: 102.7927 - learning_rate: 3.5481e-04
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 101.3005 - mae: 101.7986 - learning_rate: 3.9811e-04
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 100.4234 - mae: 100.9219 - learning_rate: 4.4668e-04
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 99.6739 - mae: 100.1721 - learning_rate: 5.0119e-04
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 98.1661 - mae: 98.6650 - learning_rate: 5.6234e-04
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 97.3835 - mae: 97.8798 - learning_rate: 6.3096e-04
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 95.9473 - mae: 96.4445 - learning_rate: 7.0795e-04
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 94.1445 - mae: 94.6421 - learning_rate: 7.9433e-04
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 92.3260 - mae: 92.8228 - learning_rate: 8.9125e-04

# %% [markdown]
# - 안정적 상태에서 최소 mae 를 얻은 learning rate 선택

# %%
plt.plot(history.history["loss"])

# %%
# x축을 로그 스케일로 학습률(lr)에 따른 손실(loss) 변화 시각화
plt.semilogx(history.history["learning_rate"], history.history["loss"])

# 축 범위 설정: x축 (학습률 범위), y축 (손실 범위)
plt.axis([1e-7, 1e-4, 90, 115])
# Out:
# (np.float64(1e-07), np.float64(0.0001), np.float64(90.0), np.float64(115.0))

# %% [markdown]
# 이 코드에서 `np.argmin`을 사용하여 최소 손실 값에 해당하는 인덱스를 찾고, 해당 인덱스의 learning rate를 선택합니다.

# %%
best_idx = np.argmin(history.history["loss"])

# %%
best_lr = history.history['learning_rate'][best_idx]
best_lr
# Out:
# 0.0008912509656511247

# %% [markdown]
# ### Hyper Parameter Tuning
#
# - optimal learning rate로 충분한 epoch train
#     - optimal lr <-- best_lr
#     - epochs <-- 300
#
# - kernel size를 3으로 조정

# %%
tf.keras.backend.clear_session()
EPOCHS = 300

train_set = windowed_dataset(X_train, window_size,
                    batch_size, shuffle_buffer_size)

model = model_define(kernel_size=3)

optimizer = tf.keras.optimizers.SGD(learning_rate=best_lr, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

history = model.fit(train_set, epochs=EPOCHS, verbose=1)
# Out:
# Epoch 1/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 108.4790 - mae: 108.9768
# Epoch 2/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 106.0064 - mae: 106.5052
# Epoch 3/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 105.5075 - mae: 106.0056
# Epoch 4/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 102.8802 - mae: 103.3787
# Epoch 5/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 102.2577 - mae: 102.7562
# Epoch 6/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 100.6162 - mae: 101.1146
# Epoch 7/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 98.8539 - mae: 99.3522
# Epoch 8/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 96.9725 - mae: 97.4691
# Epoch 9/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 95.1192 - mae: 95.6173
# Epoch 10/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 92.1683 - mae: 92.6644
# Epoch 11/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 91.4800 - mae: 91.9784
# Epoch 12/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 89.7441 - mae: 90.2412
# Epoch 13/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 87.6813 - mae: 88.1795
# Epoch 14/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 86.0450 - mae: 86.5422
# Epoch 15/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 83.8749 - mae: 84.3720
# Epoch 16/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 81.6859 - mae: 82.1827
# Epoch 17/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 80.8320 - mae: 81.3298
# Epoch 18/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 80.1880 - mae: 80.6865
# Epoch 19/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 78.7423 - mae: 79.2403
# Epoch 20/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 77.0285 - mae: 77.5261
# Epoch 21/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 76.7152 - mae: 77.2135
# Epoch 22/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 75.4574 - mae: 75.9554
# Epoch 23/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 74.6442 - mae: 75.1422
# Epoch 24/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 73.0761 - mae: 73.5747
# Epoch 25/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 71.3909 - mae: 71.8900
# Epoch 26/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 70.5719 - mae: 71.0701
# Epoch 27/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 71.0051 - mae: 71.5041
# Epoch 28/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 69.8679 - mae: 70.3663
# Epoch 29/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 72.0356 - mae: 72.5338
# Epoch 30/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 69.9669 - mae: 70.4651
# Epoch 31/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 66.9793 - mae: 67.4773
# Epoch 32/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 67.6770 - mae: 68.1746
# Epoch 33/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 67.5932 - mae: 68.0908
# Epoch 34/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 67.3977 - mae: 67.8957
# Epoch 35/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 66.2612 - mae: 66.7597
# Epoch 36/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 64.7496 - mae: 65.2473
# Epoch 37/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 61.5181 - mae: 62.0155
# Epoch 38/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 59.4678 - mae: 59.9649
# Epoch 39/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 59.4573 - mae: 59.9549
# Epoch 40/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 57.3759 - mae: 57.8722
# Epoch 41/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 55.2158 - mae: 55.7104
# Epoch 42/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 54.1083 - mae: 54.6036
# Epoch 43/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 66.7985 - mae: 67.2977
# Epoch 44/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 66.3841 - mae: 66.8825
# Epoch 45/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 62.0008 - mae: 62.4990
# Epoch 46/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 57.9235 - mae: 58.4208
# Epoch 47/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 52.7524 - mae: 53.2476
# Epoch 48/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 51.6255 - mae: 52.1207
# Epoch 49/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - loss: 49.9533 - mae: 50.4482
# Epoch 50/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 47.2930 - mae: 47.7884
# Epoch 51/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 46.6615 - mae: 47.1560
# Epoch 52/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 46.0865 - mae: 46.5816
# Epoch 53/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 44.5310 - mae: 45.0254
# Epoch 54/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 44.0644 - mae: 44.5588
# Epoch 55/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 42.5916 - mae: 43.0854
# Epoch 56/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 41.7889 - mae: 42.2835
# Epoch 57/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 41.1021 - mae: 41.5963
# Epoch 58/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 40.0986 - mae: 40.5921
# Epoch 59/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.3448 - mae: 39.8392
# Epoch 60/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 38.1284 - mae: 38.6220
# Epoch 61/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 36.2381 - mae: 36.7324
# Epoch 62/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 36.9103 - mae: 37.4031
# Epoch 63/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 36.1839 - mae: 36.6765
# Epoch 64/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 35.2197 - mae: 35.7125
# Epoch 65/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34.5688 - mae: 35.0617
# Epoch 66/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 34.2608 - mae: 34.7535
# Epoch 67/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 33.2772 - mae: 33.7699
# Epoch 68/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 32.3012 - mae: 32.7940
# Epoch 69/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 42.1817 - mae: 42.6775
# Epoch 70/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 50.6326 - mae: 51.1296
# Epoch 71/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 43.6345 - mae: 44.1299
# Epoch 72/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 40.3948 - mae: 40.8899
# Epoch 73/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 37.4641 - mae: 37.9581
# Epoch 74/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 35.8038 - mae: 36.2967
# Epoch 75/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 34.9386 - mae: 35.4318
# Epoch 76/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 40.8146 - mae: 41.3102
# Epoch 77/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 38.2594 - mae: 38.7541
# Epoch 78/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 48.6046 - mae: 49.1015
# Epoch 79/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 52.5130 - mae: 53.0104
# Epoch 80/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 48.1153 - mae: 48.6124
# Epoch 81/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 39.4872 - mae: 39.9822
# Epoch 82/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.4316 - mae: 35.9252
# Epoch 83/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 33.3428 - mae: 33.8367
# Epoch 84/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 44.6653 - mae: 45.1611
# Epoch 85/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 53.2310 - mae: 53.7294
# Epoch 86/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 38.0957 - mae: 38.5911
# Epoch 87/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 71.0176 - mae: 71.5157
# Epoch 88/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 71.9152 - mae: 72.4130
# Epoch 89/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step - loss: 70.5474 - mae: 71.0463
# Epoch 90/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss:
300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 66.7283 - mae: 67.2272
# Epoch 280/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 67.5983 - mae: 68.0966
# Epoch 281/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 68.4401 - mae: 68.9385
# Epoch 282/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 66.5776 - mae: 67.0773
# Epoch 283/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 67.1187 - mae: 67.6176
# Epoch 284/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 67.0656 - mae: 67.5647
# Epoch 285/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 66.9041 - mae: 67.4037
# Epoch 286/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 67.3657 - mae: 67.8640
# Epoch 287/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 66.7705 - mae: 67.2685
# Epoch 288/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 66.3710 - mae: 66.8692
# Epoch 289/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 66.5017 - mae: 67.0001
# Epoch 290/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 66.5138 - mae: 67.0121
# Epoch 291/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 65.8757 - mae: 66.3738
# Epoch 292/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 66.3643 - mae: 66.8626
# Epoch 293/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 66.5544 - mae: 67.0526
# Epoch 294/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 66.3273 - mae: 66.8258
# Epoch 295/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 67.2806 - mae: 67.7789
# Epoch 296/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 66.8067 - mae: 67.3050
# Epoch 297/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 65.6773 - mae: 66.1755
# Epoch 298/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 66.1813 - mae: 66.6795
# Epoch 299/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 66.2535 - mae: 66.7528
# Epoch 300/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 66.6702 - mae: 67.1679

# %% [markdown]
# 훈련 과정에서 계산된 평균 절대 오차(MAE)와 손실 값(Loss)을 시각화 합니다.

# %%
mae=history.history['mae']
loss=history.history['loss']

plt.plot(mae, 'r', label='MAE')
plt.plot(loss, 'b', label='Loss')
plt.title('Batch size = {}'.format(batch_size))
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend()

# %%
print(time_series.shape)
print(X_test.shape)
# Out:
# (1000,)
# (300,)

# %% [markdown]
# X_test data 를 이용하여 forecast

# %%
forecast = model_forecast(model, X_test, window_size)
forecast.shape
# Out:
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# (169, 132, 1)

# %%
forecast = forecast[:, -1, 0]
forecast.shape
# Out:
# (169,)

# %% [markdown]
# ### True value와 prediction value 비교 시각화

# %% [markdown]
# X_test(실제 값)와 forecast(예측 값)을 시계열 데이터로 시각화하는 코드입니다.
#
# plt.plot() 함수를 사용하여 time_test와 X_test(실제 값)를 그래프로 그리고, 범례 레이블을 'True'로 설정합니다.
# plt.plot() 함수를 사용하여 time_test의 끝부분에서 예측된 값의 길이만큼과 forecast(예측 값)를 그래프로 그리고, 범례 레이블을 'Forecast'로 설정합니다.
#
# 초반 window_size 만큼의 데이터는 예측 과정에서 skip되므로, 그래프에서도 그 부분이 생략되어 그려집니다.

# %%
plt.figure(figsize=(16, 6))
plt.plot(time_test, X_test, label='True')
plt.plot(time_test[-len(forecast):] , forecast, label='Forecast')
plt.xlabel("Time")
plt.ylabel("Value")
plt.xticks([50, 100, 150, 200, 250])
plt.grid(True)
plt.legend()

# %% [markdown]
# X_test와 forecast 간의 평균 제곱 오차(mean squared error, MSE)와 평균 절대 오차(mean absolute error, MAE)를 계산하고 출력합니다.

# %%
print(f"MSE: {mean_squared_error(X_test[window_size-1:], forecast):.4f}")
print(f"MAE: {mean_absolute_error(X_test[window_size-1:], forecast):.4f}")
# Out:
# MSE: 2404.0345
# MAE: 43.0621

# %% [markdown]
# ## Window Size를 바꾸어 가며 Tuning
#
# 11 년 주기의 noise 가 심한 data 이므로 다양한 size 의 window 를 try 하며 model tuning --> 132, 30, 64 등
